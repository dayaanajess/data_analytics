# %% [markdown]
# # First lesson modul 2 - Jipyter
# ### markdownguide смотреть там примеры письма on english only

# %%
print('Jupyter')
# Out:
# Jupyter

# %%
# Установка библиотеки NumPy
# %pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.0 kB 262.6 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.0 kB 262.6 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.0 kB 262.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 175.0 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 191.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/15.5 MB 991.0 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/15.5 MB 1.1 MB/s eta 0:00:15
#    ---------------------------------------- 0.1/15.5 MB 1.1 MB/s eta 0:00:15
# ...

# %%
# импортирование NumPy
import numpy as np

# %%
# создание массива на базе списка
lst_1 = [1, 6, 8, 7, 5]

# %%
arr_1 = np.array(lst_1)

# %%
arr_1
# Out:
# array([1, 6, 8, 7, 5])
